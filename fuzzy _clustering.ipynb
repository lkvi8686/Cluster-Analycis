# %%
# ! pip install fuzzy-c-means

# %%
from fcmeans import FCM
from sklearn.datasets import make_blobs

# %%
import pandas as pd
import os as os
import skfuzzy as fuzz

# %%
os.chdir(r'C:\Users\Sharath Chandra\Desktop\Analytics Model developement')

# %%
df = pd.read_csv(r'C:\Users\Sharath Chandra\Desktop\Analytics Model developement\ZASE_dataFile.csv')
df
# Out:
#       record              uuid  Z_ASE1  Z_ASE2  Z_ASE3  Z_ASE4  Z_ASE5  \
# 0        163  zk09huxyjzdgqt64    2.40    2.26    1.68    2.55    4.70
# 1        166  ygs2utvtfft1xryu    3.46    3.46    1.51    3.46    2.03
# 2        172  sfv522dpjck33v24    0.23    0.59    0.50    0.50    0.50
# 3        175  mw11mryb779z7ug9    3.93    0.28    0.31    0.37    0.17
# 4        180  s225d9fuhjuxy31m    4.93    4.93    0.99    4.93    0.63
# 5        184  ue9f05zg6d25q8x2    2.06    2.37    2.49    2.20    4.10
# 6        185  k7v8e3nkwz8u6820    3.99    3.98    0.69    1.01    4.06
# 7        188  c2spepca0p8x14xb    1.60    1.78    3.02    1.59    2.30
# 8        195  ka7ffmj37vbkgrem    0.80    3.87    0.76    3.70    3.70
# 9        197  ehsh4ns70kdzsrxt    2.13    2.97    2.48    1.65    1.65
# 10       198  ex77sbs52eehp3tm    1.25    1.25    1.25    1.55    1.25
# 11       200  j8f5gdpae2kck2nv    0.54    0.79    0.44    1.18    5.38
# ...

# %%
df1 = df.filter(regex='Z_ASE')

# %%
from fcmeans import FCM
from matplotlib import pyplot as plt
# from seaborn import scatterplot as scatter

# fit the fuzzy-c-means
fcm = FCM(n_clusters=3,m=2,max_iter=10000)
fcm.fit(df1)

# outputs
fcm_centers = fcm.centers
fcm_labels  = fcm.u.argmax()

# plot result
# %matplotlib inline
# f, axes = plt.subplots(1, 2, figsize=(11,5))
# scatter(X[:,0], X[:,1], ax=axes[0])
# scatter(X[:,0], X[:,1], ax=axes[1], hue=fcm_labels)
# scatter(fcm_centers[:,0], fcm_centers[:,1], ax=axes[1],marker="s",s=200)
# plt.show()

# %%
df['label']=fcm.u.argmax(axis=1)

# %%
df['label'].value_counts()
# Out:
# 0    2245
# 1    1570
# Name: label, dtype: int64

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps=4).fit(df1)
# core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
# core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# %%
df1['label1']=labels
# Out:
# C:\Users\Sharath Chandra\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['label1'].value_counts()
# Out:
# -1    3529
#  0     279
#  1       7
# Name: label1, dtype: int64

# %%
import sklearn.mixture as SM

# %%
fit=SM.GaussianMixture(n_components=7).fit(df1)

# %%
lables =fit.predict(df1)

# %%
df['lables']=lables

# %%
df['lables'].value_counts()
# Out:
# 0    1343
# 4     705
# 3     531
# 6     472
# 5     425
# 2     279
# 1      60
# Name: lables, dtype: int64
